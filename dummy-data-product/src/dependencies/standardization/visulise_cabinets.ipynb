# %% [markdown]
# # importing dependency

# %%
import re
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')
print(df.columns)
# Out:
# Index(['Contracts', 'Agency name', 'Description', 'Procurment stage',
#        'Contract location', 'Awarded value', 'Awarded supplier',
#        'Publiscation date'],
#       dtype='object')

# %%
df.describe()
# Out:
#                                                 Contracts  \
# count                                                  60
# unique                                                 51
# top     Provision of Cabinet Office Consultancy Suppor...
# freq                                                    6
#
#                             Agency name  \
# count                                60
# unique                               27
# top     Cabinet Office : Cabinet Office
# freq                                 30
#
#                                     Description  \
# count                                        60
# unique                                       50
# top     Cabinet Office Consultancy Arrangements
# freq                                          6
#
#                           Procurment stage         Contract location  \
# count                                   60                        60
# unique                                   1                        21
# ...

# %%
df.head()
# Out:
#                                            Contracts  \
# 0  Maintenance of Laminar Flow Cabinets and Safet...
# 1              ORT0050 - Cabinets & Associated Items
# 2  Mechanical, Electrical and Networking Works fo...
# 3                  TMTii 01 - Order 9 - Hill & Smith
# 4  (NU/1645) The Supply of a Hydrogen Peroxide Va...
#
#                                          Agency name  \
# 0                             NHS Blood & Transplant
# 1                          NATIONAL HIGHWAYS LIMITED
# 2  NHS ARDEN AND GREATER EAST MIDLANDS COMMISSION...
# 3                                    Highways Agency
# 4                               Newcastle University
#
#                                          Description  \
# 0  ...Safety Cabinets (MSC) and Laminar Air Flow ...
# 1  "CABINET-0014-1-000 - T - Key Standard (to MCX...
# 2  ...cabinets • Installation of uninterruptable....
# 3  Cabinet 609D Complete - Includes CABINET-0009-...
# ...

# %%
df["Awarded_price"]=["".join((re.findall(r'\d+',i))) for i in df["Awarded value"]]
df['Year']=[i.split()[2:5][-1] for i in df["Publiscation date"]]
df["Month"]=[i.split()[2:5][-2] for i in df["Publiscation date"]]

df
# Out:
#                                             Contracts  \
# 0   Maintenance of Laminar Flow Cabinets and Safet...
# 1               ORT0050 - Cabinets & Associated Items
# 2   Mechanical, Electrical and Networking Works fo...
# 3                   TMTii 01 - Order 9 - Hill & Smith
# 4   (NU/1645) The Supply of a Hydrogen Peroxide Va...
# 5   Provision of Cabinet Refresh in Lincolnshire f...
# 6   2335/JS - MRI PET Facility - Shielded Laminar ...
# 7   Safety Cabinet, Laminar Flow Cabinet, Isolator...
# 8                         MSC Phase 1 - Regional Labs
# 9                                         MSC Phase 1
# 10  Review of bullying, harassment and discriminat...
# 11                Class II Safety Cabinets for Porton
# 12  Service and Maintenance of Microbiological Saf...
# 13  Defibrillators, Defibrillator Cabinets & Defib...
# 14            Class 1 Microbiological Safety Cabinets
# 15  CAS- Purchase of Robotic Class II Microbiologi...
# ...

# %%
df
# Out:
#                                             Contracts  \
# 0   Maintenance of Laminar Flow Cabinets and Safet...
# 1               ORT0050 - Cabinets & Associated Items
# 2   Mechanical, Electrical and Networking Works fo...
# 3                   TMTii 01 - Order 9 - Hill & Smith
# 4   (NU/1645) The Supply of a Hydrogen Peroxide Va...
# 5   Provision of Cabinet Refresh in Lincolnshire f...
# 6   2335/JS - MRI PET Facility - Shielded Laminar ...
# 7   Safety Cabinet, Laminar Flow Cabinet, Isolator...
# 8                         MSC Phase 1 - Regional Labs
# 9                                         MSC Phase 1
# 10  Review of bullying, harassment and discriminat...
# 11                Class II Safety Cabinets for Porton
# 12  Service and Maintenance of Microbiological Saf...
# 13  Defibrillators, Defibrillator Cabinets & Defib...
# 14            Class 1 Microbiological Safety Cabinets
# 15  CAS- Purchase of Robotic Class II Microbiologi...
# ...

# %%
month_list = ['December', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November']

# %% [markdown]
# # no of cabinet tenders released in each year

# %%
sns.countplot(df['Year'])
plt.show()
# Out:
# c:\users\rsi\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
l=[i[17:].split(',')[0]  for i in df['Contract location'] if i != 'Any region' ]

# %% [markdown]
# # tenders won by each country

# %%
sns.countplot(l)
# Out:
# c:\users\rsi\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>
